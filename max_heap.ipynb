# %% [markdown]
# # Max Heap Walkthrough
#
# Visualize a max-heap as a binary tree using NetworkX.
# We start empty, insert random values one at a time, then pop the max.

# %%
import random
from algopy.utilities import draw_heap
from algopy.data_structures import MaxHeap

# %matplotlib inline

# %% [markdown]
# ## 1. Empty Heap

# %%
h = MaxHeap()
draw_heap(h.to_networkx(), title="Empty Heap")

# %% [markdown]
# ## 2. Insert Elements
#
# Insert random integers one at a time and draw the heap after each insertion.

# %%
random.seed(42)
values = random.sample(range(1, 100), 15)

for v in values:
    h.insert(f"node_{v}", v)
    draw_heap(h.to_networkx(), title=f"After insert('node_{v}', {v})  --  array: {[e['value'] for e in h.elements]}")

# %% [markdown]
# ## 3. Pop the Max
#
# Remove the root (maximum element) and show the heap after it re-heapifies.

# %%
popped = h.pop()
print(f"Popped: {popped}")
draw_heap(h.to_networkx(), title=f"After pop() returned {popped['value']}  --  array: {[e['value'] for e in h.elements]}")
# Out:
# Popped: {'item': 'node_95', 'value': 95}
